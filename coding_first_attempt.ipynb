# %%
import pandas as pd
import numpy as np

# %%
first_attempt_to_load = "Working_Data.csv"

# %%
first_attempt_to_load
# Out:
# 'Working_Data.csv'

# %%
first_attempt_df = pd.read_csv(first_attempt_to_load, index_col=0)
first_attempt_df.head(10)
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
# 5       2020               EN              FT                Data Analyst
# 6       2020               SE              FT         Lead Data Scientist
# 7       2020               MI              FT              Data Scientist
# 8       2020               MI              FT       Business Data Analyst
# 9       2020               SE              FT          Lead Data Engineer
#
#             salary  salary_currency  salary_in_usd  employee_residence  \
# 0       $70,000.00              EUR     $79,833.00                  DE
# 1      $260,000.00              USD    $260,000.00                  JP
# 2       $85,000.00              GBP    $109,024.00                  GB
# 3       $20,000.00              USD     $20,000.00                  HN
# 4      $150,000.00              USD    $150,000.00                  US
# 5       $72,000.00              USD     $72,000.00                  US
# 6      $190,000.00              USD    $190,000.00                  US
# 7   $11,000,000.00              HUF     $35,735.00                  HU
# 8      $135,000.00              USD    $135,000.00                  US
# 9      $125,000.00              USD    $125,000.00                  NZ
#
#    remote_ratio company_location company_size
# 0             0               DE            L
# 1             0               JP            S
# 2            50               GB            M
# 3             0               HN            S
# 4            50               US            L
# 5           100               US            L
# 6           100               US            S
# 7            50               HU            L
# 8           100               US            L
# 9            50               NZ            S

# %%
L_company_df = first_attempt_df[first_attempt_df['company_size'] == "L"]
L_company_df
# Out:
#      work_year experience_level employment_type                  job_title  \
# 0         2020               MI              FT             Data Scientist
# 4         2020               SE              FT  Machine Learning Engineer
# 5         2020               EN              FT               Data Analyst
# 7         2020               MI              FT             Data Scientist
# 8         2020               MI              FT      Business Data Analyst
# ..         ...              ...             ...                        ...
# 524       2022               MI              FT             Data Scientist
# 525       2022               SE              FT     Applied Data Scientist
# 550       2022               SE              FT             Data Scientist
# 551       2022               SE              FT             Data Scientist
# 606       2022               MI              FT               AI Scientist
#
#               salary  salary_currency  salary_in_usd  employee_residence  \
# 0         $70,000.00              EUR     $79,833.00                  DE
# 4        $150,000.00              USD    $150,000.00                  US
# 5         $72,000.00              USD     $72,000.00                  US
# 7     $11,000,000.00              HUF     $35,735.00                  HU
# 8        $135,000.00              USD    $135,000.00                  US
# ..                ...             ...             ...                ...
# 524      $135,000.00              USD    $135,000.00                  US
# 525      $177,000.00              USD    $177,000.00                  US
# 550      $205,300.00              USD    $205,300.00                  US
# 551      $140,400.00              USD    $140,400.00                  US
# 606      $200,000.00              USD    $200,000.00                  IN
#
#      remote_ratio company_location company_size
# 0               0               DE            L
# 4              50               US            L
# 5             100               US            L
# 7              50               HU            L
# 8             100               US            L
# ..            ...              ...          ...
# 524           100               US            L
# 525           100               US            L
# 550             0               US            L
# 551             0               US            L
# 606           100               US            L
#
# [198 rows x 11 columns]

# %%
M_company_df = first_attempt_df[first_attempt_df['company_size'] == "M"]
M_company_df
# Out:
#      work_year experience_level employment_type                  job_title  \
# 2         2020               SE              FT          Big Data Engineer
# 12        2020               EN              FT             Data Scientist
# 18        2020               EN              FT    Data Science Consultant
# 19        2020               MI              FT         Lead Data Engineer
# 20        2020               MI              FT  Machine Learning Engineer
# ..         ...              ...             ...                        ...
# 601       2022               EN              FT               Data Analyst
# 602       2022               SE              FT              Data Engineer
# 603       2022               SE              FT              Data Engineer
# 604       2022               SE              FT               Data Analyst
# 605       2022               SE              FT               Data Analyst
#
#            salary  salary_currency  salary_in_usd  employee_residence  \
# 2      $85,000.00              GBP    $109,024.00                  GB
# 12     $35,000.00              EUR     $39,916.00                  FR
# 18    $423,000.00              INR      $5,707.00                  IN
# 19     $56,000.00              USD     $56,000.00                  PT
# 20    $299,000.00              CNY     $43,331.00                  CN
# ..             ...             ...             ...                ...
# 601    $52,000.00              USD     $52,000.00                  CA
# 602   $154,000.00              USD    $154,000.00                  US
# 603   $126,000.00              USD    $126,000.00                  US
# 604   $129,000.00              USD    $129,000.00                  US
# 605   $150,000.00              USD    $150,000.00                  US
#
#      remote_ratio company_location company_size
# 2              50               GB            M
# 12              0               FR            M
# 18             50               IN            M
# 19            100               US            M
# 20              0               CN            M
# ..            ...              ...          ...
# 601             0               CA            M
# 602           100               US            M
# 603           100               US            M
# 604             0               US            M
# 605           100               US            M
#
# [326 rows x 11 columns]

# %%
S_company_df = first_attempt_df[first_attempt_df['company_size'] == "S"]
S_company_df
# Out:
#      work_year experience_level employment_type  \
# 1         2020               SE              FT
# 3         2020               MI              FT
# 6         2020               SE              FT
# 9         2020               SE              FT
# 10        2020               EN              FT
# ..         ...              ...             ...
# 510       2022               EN              FT
# 512       2022               EN              FT
# 513       2022               SE              FT
# 515       2022               MI              FT
# 522       2022               MI              FT
#
#                              job_title        salary  salary_currency  \
# 1           Machine Learning Scientist   $260,000.00              USD
# 3                 Product Data Analyst    $20,000.00              USD
# 6                  Lead Data Scientist   $190,000.00              USD
# 9                   Lead Data Engineer   $125,000.00              USD
# 10                      Data Scientist    $45,000.00              EUR
# ..                                 ...            ...             ...
# 510  Computer Vision Software Engineer   $150,000.00              USD
# 512                      Data Engineer    $65,000.00              USD
# 513          Machine Learning Engineer    $65,000.00              EUR
# 515                     Data Scientist    $48,000.00              USD
# 522                       Data Analyst    $20,000.00              USD
#
#      salary_in_usd  employee_residence  remote_ratio company_location  \
# 1      $260,000.00                  JP             0               JP
# 3       $20,000.00                  HN             0               HN
# 6      $190,000.00                  US           100               US
# 9      $125,000.00                  NZ            50               NZ
# 10      $51,321.00                  FR             0               FR
# ..              ...                ...           ...              ...
# 510    $150,000.00                  AU           100               AU
# 512     $65,000.00                  US           100               US
# 513     $71,444.00                  IE           100               IE
# 515     $48,000.00                  RU           100               US
# 522     $20,000.00                  GR           100               GR
#
#     company_size
# 1              S
# 3              S
# 6              S
# 9              S
# 10             S
# ..           ...
# 510            S
# 512            S
# 513            S
# 515            S
# 522            S
#
# [83 rows x 11 columns]

# %%
slim_df = df[['salary_in_usd']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18424\3552942856.py in <module>
# ----> 1 slim_df = df[['salary_in_usd']]
#
# NameError: name 'df' is not defined
