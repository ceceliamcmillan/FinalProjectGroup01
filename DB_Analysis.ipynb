# %%
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import session
from sqlalchemy import create_engine
from config import db_password

# %%
starting_data = "Working_Data.csv"

# %%
starting_data
# Out:
# 'Working_Data.csv'

# %%
starting_data_df = pd.read_csv(starting_data, index_col=0)
starting_data_df.head(10)
# Out:
#             work_year experience_level employment_type  \
# Uni_number
# 0                2020               MI              FT
# 1                2020               SE              FT
# 2                2020               SE              FT
# 3                2020               MI              FT
# 4                2020               SE              FT
# 5                2020               EN              FT
# 6                2020               SE              FT
# 7                2020               MI              FT
# 8                2020               MI              FT
# 9                2020               SE              FT
#
#                              job_title   salary  salary_currency  \
# Uni_number
# 0                       Data Scientist     70000             EUR
# 1           Machine Learning Scientist    260000             USD
# 2                    Big Data Engineer     85000             GBP
# 3                 Product Data Analyst     20000             USD
# 4            Machine Learning Engineer    150000             USD
# 5                         Data Analyst     72000             USD
# 6                  Lead Data Scientist    190000             USD
# 7                       Data Scientist  11000000             HUF
# 8                Business Data Analyst    135000             USD
# 9                   Lead Data Engineer    125000             USD
#
#              salary_in_usd  employee_residence  remote_ratio company_location  \
# Uni_number
# 0                     79833                 DE             0               DE
# 1                    260000                 JP             0               JP
# 2                    109024                 GB            50               GB
# 3                     20000                 HN             0               HN
# 4                    150000                 US            50               US
# 5                     72000                 US           100               US
# 6                    190000                 US           100               US
# 7                     35735                 HU            50               HU
# 8                    135000                 US           100               US
# 9                    125000                 NZ            50               NZ
#
#            company_size
# Uni_number
# 0                     L
# 1                     S
# 2                     M
# 3                     S
# 4                     L
# 5                     L
# 6                     S
# 7                     L
# 8                     L
# 9                     S

# %%
us_df = starting_data_df[starting_data_df['employee_residence'] == "US"]
us_df
# Out:
#             work_year experience_level employment_type  \
# Uni_number
# 4                2020               SE              FT
# 5                2020               EN              FT
# 6                2020               SE              FT
# 8                2020               MI              FT
# 13               2020               MI              FT
# ...               ...              ...             ...
# 599              2022               MI              FT
# 602              2022               SE              FT
# 603              2022               SE              FT
# 604              2022               SE              FT
# 605              2022               SE              FT
#
#                             job_title   salary  salary_currency  \
# Uni_number
# 4           Machine Learning Engineer    150000             USD
# 5                        Data Analyst     72000             USD
# 6                 Lead Data Scientist    190000             USD
# 8               Business Data Analyst    135000             USD
# 13                  Lead Data Analyst     87000             USD
# ...                               ...       ...             ...
# 599                    Data Scientist    130000             USD
# 602                     Data Engineer    154000             USD
# 603                     Data Engineer    126000             USD
# 604                      Data Analyst    129000             USD
# 605                      Data Analyst    150000             USD
#
#              salary_in_usd  employee_residence  remote_ratio company_location  \
# Uni_number
# 4                    150000                 US            50               US
# 5                     72000                 US           100               US
# 6                    190000                 US           100               US
# 8                    135000                 US           100               US
# 13                    87000                 US           100               US
# ...                     ...                ...           ...              ...
# 599                  130000                 US           100               US
# 602                  154000                 US           100               US
# 603                  126000                 US           100               US
# 604                  129000                 US             0               US
# 605                  150000                 US           100               US
#
#            company_size
# Uni_number
# 4                     L
# 5                     L
# 6                     S
# 8                     L
# 13                    L
# ...                 ...
# 599                   M
# 602                   M
# 603                   M
# 604                   M
# 605                   M
#
# [332 rows x 11 columns]

# %%
us_df['job_title'].value_counts()
# Out:
# Data Engineer                               82
# Data Scientist                              78
# Data Analyst                                70
# Machine Learning Engineer                   16
# Data Science Manager                        10
# Data Architect                               9
# Data Analytics Manager                       7
# Machine Learning Scientist                   6
# Analytics Engineer                           4
# Principal Data Scientist                     4
# Principal Data Engineer                      3
# Data Engineering Manager                     3
# Research Scientist                           3
# BI Data Analyst                              3
# Applied Data Scientist                       3
# Head of Data Science                         3
# ML Engineer                                  2
# Financial Data Analyst                       2
# Lead Data Analyst                            2
# Director of Data Science                     2
# Data Science Consultant                      2
# Business Data Analyst                        2
# NLP Engineer                                 1
# Computer Vision Engineer                     1
# AI Scientist                                 1
# Director of Data Engineering                 1
# Staff Data Scientist                         1
# Principal Data Analyst                       1
# Applied Machine Learning Scientist           1
# Machine Learning Infrastructure Engineer     1
# Lead Data Scientist                          1
# Data Specialist                              1
# Computer Vision Software Engineer            1
# Lead Data Engineer                           1
# Data Analytics Engineer                      1
# Head of Data                                 1
# Big Data Engineer                            1
# Data Analytics Lead                          1
# Name: job_title, dtype: int64

# %%
Data_Engineer_df = us_df[us_df['job_title'] == "Data Engineer"]
Data_Engineer_df
# Out:
#             work_year experience_level employment_type      job_title  \
# Uni_number
# 43               2020               MI              FT  Data Engineer
# 47               2020               SE              FT  Data Engineer
# 60               2020               MI              FT  Data Engineer
# 81               2021               MI              FT  Data Engineer
# 101              2021               SE              FT  Data Engineer
# ...               ...              ...             ...            ...
# 579              2022               SE              FT  Data Engineer
# 582              2022               SE              FT  Data Engineer
# 583              2022               SE              FT  Data Engineer
# 602              2022               SE              FT  Data Engineer
# 603              2022               SE              FT  Data Engineer
#
#              salary  salary_currency   salary_in_usd  employee_residence  \
# Uni_number
# 43            106000             USD           106000                 US
# 47            188000             USD           188000                 US
# 60            110000             USD           110000                 US
# 81            140000             USD           140000                 US
# 101           150000             USD           150000                 US
# ...              ...             ...              ...                ...
# 579            25000             USD            25000                 US
# 582           220110             USD           220110                 US
# 583           160080             USD           160080                 US
# 602           154000             USD           154000                 US
# 603           126000             USD           126000                 US
#
#             remote_ratio company_location company_size
# Uni_number
# 43                   100               US            L
# 47                   100               US            L
# 60                   100               US            L
# 81                   100               US            L
# 101                  100               US            L
# ...                  ...              ...          ...
# 579                  100               US            M
# 582                  100               US            M
# 583                  100               US            M
# 602                  100               US            M
# 603                  100               US            M
#
# [82 rows x 11 columns]

# %%
Data_Scientist_df = us_df[us_df['job_title'] == "Data Scientist"]
Data_Scientist_df
# Out:
#             work_year experience_level employment_type       job_title  \
# Uni_number
# 48               2020               MI              FT  Data Scientist
# 57               2020               MI              FT  Data Scientist
# 58               2020               SE              FT  Data Scientist
# 59               2020               MI              FT  Data Scientist
# 63               2020               SE              FT  Data Scientist
# ...               ...              ...             ...             ...
# 592              2022               SE              FT  Data Scientist
# 593              2022               SE              FT  Data Scientist
# 596              2022               SE              FT  Data Scientist
# 598              2022               MI              FT  Data Scientist
# 599              2022               MI              FT  Data Scientist
#
#              salary  salary_currency   salary_in_usd  employee_residence  \
# Uni_number
# 48            105000             USD           105000                 US
# 57            118000             USD           118000                 US
# 58            120000             USD           120000                 US
# 59            138350             USD           138350                 US
# 63            412000             USD           412000                 US
# ...              ...             ...              ...                ...
# 592           230000             USD           230000                 US
# 593           150000             USD           150000                 US
# 596           210000             USD           210000                 US
# 598           160000             USD           160000                 US
# 599           130000             USD           130000                 US
#
#             remote_ratio company_location company_size
# Uni_number
# 48                   100               US            L
# 57                   100               US            M
# 58                    50               US            L
# 59                   100               US            M
# 63                   100               US            L
# ...                  ...              ...          ...
# 592                  100               US            M
# 593                  100               US            M
# 596                  100               US            M
# 598                  100               US            M
# 599                  100               US            M
#
# [78 rows x 11 columns]

# %%
Data_Analyst_df = us_df[us_df['job_title'] == "Data Analyst"]
Data_Analyst_df
# Out:
#             work_year experience_level employment_type     job_title  \
# Uni_number
# 5                2020               EN              FT  Data Analyst
# 14               2020               MI              FT  Data Analyst
# 51               2020               EN              FT  Data Analyst
# 79               2021               EN              FT  Data Analyst
# 100              2021               MI              FT  Data Analyst
# ...               ...              ...             ...           ...
# 588              2022               SE              FT  Data Analyst
# 589              2022               SE              FT  Data Analyst
# 597              2022               SE              FT  Data Analyst
# 604              2022               SE              FT  Data Analyst
# 605              2022               SE              FT  Data Analyst
#
#              salary  salary_currency   salary_in_usd  employee_residence  \
# Uni_number
# 5              72000             USD            72000                 US
# 14             85000             USD            85000                 US
# 51             91000             USD            91000                 US
# 79             80000             USD            80000                 US
# 100            75000             USD            75000                 US
# ...              ...             ...              ...                ...
# 588            99000             USD            99000                 US
# 589            60000             USD            60000                 US
# 597           170000             USD           170000                 US
# 604           129000             USD           129000                 US
# 605           150000             USD           150000                 US
#
#             remote_ratio company_location company_size
# Uni_number
# 5                    100               US            L
# 14                   100               US            L
# 51                   100               US            L
# 79                   100               US            M
# 100                    0               US            L
# ...                  ...              ...          ...
# 588                    0               US            M
# 589                  100               US            M
# 597                  100               US            M
# 604                    0               US            M
# 605                  100               US            M
#
# [70 rows x 11 columns]

# %%
L_company_df = Data_Engineer_df[Data_Engineer_df['company_size'] == "L"]
L_company_df
# Out:
#             work_year experience_level employment_type      job_title  \
# Uni_number
# 43               2020               MI              FT  Data Engineer
# 47               2020               SE              FT  Data Engineer
# 60               2020               MI              FT  Data Engineer
# 81               2021               MI              FT  Data Engineer
# 101              2021               SE              FT  Data Engineer
# 119              2021               MI              FT  Data Engineer
# 144              2021               MI              FT  Data Engineer
# 147              2021               MI              FT  Data Engineer
# 166              2021               EN              FT  Data Engineer
# 242              2021               MI              FT  Data Engineer
# 256              2021               MI              FT  Data Engineer
# 270              2021               EN              FT  Data Engineer
# 280              2021               MI              FT  Data Engineer
# 348              2022               SE              FT  Data Engineer
# 364              2022               SE              FT  Data Engineer
# 400              2022               SE              FT  Data Engineer
# 401              2022               SE              FT  Data Engineer
# 407              2022               SE              FT  Data Engineer
# 426              2022               SE              FT  Data Engineer
# 446              2022               SE              FT  Data Engineer
# 447              2022               SE              FT  Data Engineer
#
#              salary  salary_currency   salary_in_usd  employee_residence  \
# Uni_number
# 43            106000             USD           106000                 US
# 47            188000             USD           188000                 US
# 60            110000             USD           110000                 US
# 81            140000             USD           140000                 US
# 101           150000             USD           150000                 US
# 119           200000             USD           200000                 US
# 144           100000             USD           100000                 US
# 147            90000             USD            90000                 US
# 166            80000             USD            80000                 US
# 242           110000             USD           110000                 US
# 256           200000             USD           200000                 US
# 270            72500             USD            72500                 US
# 280           112000             USD           112000                 US
# 348           113000             USD           113000                 US
# 364           160000             USD           160000                 US
# 400           209100             USD           209100                 US
# 401           154600             USD           154600                 US
# 407           183600             USD           183600                 US
# 426           100800             USD           100800                 US
# 446           209100             USD           209100                 US
# 447           154600             USD           154600                 US
#
#             remote_ratio company_location company_size
# Uni_number
# 43                   100               US            L
# 47                   100               US            L
# 60                   100               US            L
# 81                   100               US            L
# 101                  100               US            L
# 119                  100               US            L
# 144                  100               US            L
# 147                  100               US            L
# 166                  100               US            L
# 242                  100               US            L
# 256                  100               US            L
# 270                  100               US            L
# 280                  100               US            L
# 348                    0               US            L
# 364                    0               US            L
# 400                  100               US            L
# 401                  100               US            L
# 407                  100               US            L
# 426                  100               US            L
# 446                  100               US            L
# 447                  100               US            L

# %%
L_company_df.describe()
# Out:
#          work_year        salary    salary_in_usd   remote_ratio
# count    21.000000      21.000000        21.000000      21.00000
# mean   2021.238095  140157.142857    140157.142857      90.47619
# std       0.700340   44800.821102     44800.821102      30.07926
# min    2020.000000   72500.000000     72500.000000       0.00000
# 25%    2021.000000  106000.000000    106000.000000     100.00000
# 50%    2021.000000  140000.000000    140000.000000     100.00000
# 75%    2022.000000  183600.000000    183600.000000     100.00000
# max    2022.000000  209100.000000    209100.000000     100.00000

# %%
top_3_df = us_df.loc[us_df['job_title'].isin(["Data Engineer", "Data Scientist", "Data Analyst"])]

# %%
top_3_df
# Out:
#             work_year experience_level employment_type       job_title  \
# Uni_number
# 5                2020               EN              FT    Data Analyst
# 14               2020               MI              FT    Data Analyst
# 43               2020               MI              FT   Data Engineer
# 47               2020               SE              FT   Data Engineer
# 48               2020               MI              FT  Data Scientist
# ...               ...              ...             ...             ...
# 599              2022               MI              FT  Data Scientist
# 602              2022               SE              FT   Data Engineer
# 603              2022               SE              FT   Data Engineer
# 604              2022               SE              FT    Data Analyst
# 605              2022               SE              FT    Data Analyst
#
#              salary  salary_currency   salary_in_usd  employee_residence  \
# Uni_number
# 5              72000             USD            72000                 US
# 14             85000             USD            85000                 US
# 43            106000             USD           106000                 US
# 47            188000             USD           188000                 US
# 48            105000             USD           105000                 US
# ...              ...             ...              ...                ...
# 599           130000             USD           130000                 US
# 602           154000             USD           154000                 US
# 603           126000             USD           126000                 US
# 604           129000             USD           129000                 US
# 605           150000             USD           150000                 US
#
#             remote_ratio company_location company_size
# Uni_number
# 5                    100               US            L
# 14                   100               US            L
# 43                   100               US            L
# 47                   100               US            L
# 48                   100               US            L
# ...                  ...              ...          ...
# 599                  100               US            M
# 602                  100               US            M
# 603                  100               US            M
# 604                    0               US            M
# 605                  100               US            M
#
# [230 rows x 11 columns]

# %%
L_company_df = top_3_df[top_3_df['company_size'] == "L"]
L_company_df
# Out:
#             work_year experience_level employment_type       job_title  \
# Uni_number
# 5                2020               EN              FT    Data Analyst
# 14               2020               MI              FT    Data Analyst
# 43               2020               MI              FT   Data Engineer
# 47               2020               SE              FT   Data Engineer
# 48               2020               MI              FT  Data Scientist
# 51               2020               EN              FT    Data Analyst
# 58               2020               SE              FT  Data Scientist
# 60               2020               MI              FT   Data Engineer
# 63               2020               SE              FT  Data Scientist
# 81               2021               MI              FT   Data Engineer
# 100              2021               MI              FT    Data Analyst
# 101              2021               SE              FT   Data Engineer
# 103              2021               MI              FT    Data Analyst
# 104              2021               MI              FT  Data Scientist
# 119              2021               MI              FT   Data Engineer
# 140              2021               MI              FT    Data Analyst
# 144              2021               MI              FT   Data Engineer
# 147              2021               MI              FT   Data Engineer
# 166              2021               EN              FT   Data Engineer
# 195              2021               MI              FT  Data Scientist
# 204              2021               MI              FT  Data Scientist
# 228              2021               SE              FT  Data Scientist
# 233              2021               SE              FT    Data Analyst
# 241              2021               MI              FT    Data Analyst
# 242              2021               MI              FT   Data Engineer
# 243              2021               SE              FT  Data Scientist
# 250              2021               MI              FT  Data Scientist
# 254              2021               MI              FT    Data Analyst
# 256              2021               MI              FT   Data Engineer
# 260              2021               MI              FT  Data Scientist
# 270              2021               EN              FT   Data Engineer
# 276              2021               EN              FT  Data Scientist
# 280              2021               MI              FT   Data Engineer
# 287              2021               MI              FT  Data Scientist
# 323              2022               SE              FT  Data Scientist
# 324              2022               SE              FT  Data Scientist
# 348              2022               SE              FT   Data Engineer
# 364              2022               SE              FT   Data Engineer
# 398              2022               SE              FT  Data Scientist
# 399              2022               SE              FT  Data Scientist
# 400              2022               SE              FT   Data Engineer
# 401              2022               SE              FT   Data Engineer
# 407              2022               SE              FT   Data Engineer
# 426              2022               SE              FT   Data Engineer
# 428              2022               SE              FT  Data Scientist
# 444              2022               SE              FT  Data Scientist
# 446              2022               SE              FT   Data Engineer
# 447              2022               SE              FT   Data Engineer
# 524              2022               MI              FT  Data Scientist
# 550              2022               SE              FT  Data Scientist
# 551              2022               SE              FT  Data Scientist
#
#              salary  salary_currency   salary_in_usd  employee_residence  \
# Uni_number
# 5              72000             USD            72000                 US
# 14             85000             USD            85000                 US
# 43            106000             USD           106000                 US
# 47            188000             USD           188000                 US
# 48            105000             USD           105000                 US
# 51             91000             USD            91000                 US
# 58            120000             USD           120000                 US
# 60            110000             USD           110000                 US
# 63            412000             USD           412000                 US
# 81            140000             USD           140000                 US
# 100            75000             USD            75000                 US
# 101           150000             USD           150000                 US
# 103            62000             USD            62000                 US
# 104            73000             USD            73000                 US
# 119           200000             USD           200000                 US
# 140           135000             USD           135000                 US
# 144           100000             USD           100000                 US
# 147            90000             USD            90000                 US
# 166            80000             USD            80000                 US
# 195           147000             USD           147000                 US
# 204           160000             USD           160000                 US
# 228           135000             USD           135000                 US
# 233           200000             USD           200000                 US
# 241            80000             USD            80000                 US
# 242           110000             USD           110000                 US
# 243           165000             USD           165000                 US
# 250           115000             USD           115000                 US
# 254            93000             USD            93000                 US
# 256           200000             USD           200000                 US
# 260           130000             USD           130000                 US
# 270            72500             USD            72500                 US
# 276            58000             USD            58000                 US
# 280           112000             USD           112000                 US
# 287           109000             USD           109000                 US
# 323           180000             USD           180000                 US
# 324           120000             USD           120000                 US
# 348           113000             USD           113000                 US
# 364           160000             USD           160000                 US
# 398           215300             USD           215300                 US
# 399           158200             USD           158200                 US
# 400           209100             USD           209100                 US
# 401           154600             USD           154600                 US
# 407           183600             USD           183600                 US
# 426           100800             USD           100800                 US
# 428           140400             USD           140400                 US
# 444           215300             USD           215300                 US
# 446           209100             USD           209100                 US
# 447           154600             USD           154600                 US
# 524           135000             USD           135000                 US
# 550           205300             USD           205300                 US
# 551           140400             USD           140400                 US
#
#             remote_ratio company_location company_size
# Uni_number
# 5                    100               US            L
# 14                   100               US            L
# 43                   100               US            L
# 47                   100               US            L
# 48                   100               US            L
# 51                   100               US            L
# 58                    50               US            L
# 60                   100               US            L
# 63                   100               US            L
# 81                   100               US            L
# 100                    0               US            L
# 101                  100               US            L
# 103                    0               US            L
# 104                    0               US            L
# 119                  100               US            L
# 140                  100               US            L
# 144                  100               US            L
# 147                  100               US            L
# 166                  100               US            L
# 195                   50               US            L
# 204                  100               US            L
# 228                    0               US            L
# 233                  100               US            L
# 241                  100               US            L
# 242                  100               US            L
# 243                  100               US            L
# 250                   50               US            L
# 254                  100               US            L
# 256                  100               US            L
# 260                   50               US            L
# 270                  100               US            L
# 276                   50               US            L
# 280                  100               US            L
# 287                   50               US            L
# 323                    0               US            L
# 324                    0               US            L
# 348                    0               US            L
# 364                    0               US            L
# 398                  100               US            L
# 399                  100               US            L
# 400                  100               US            L
# 401                  100               US            L
# 407                  100               US            L
# 426                  100               US            L
# 428                    0               US            L
# 444                    0               US            L
# 446                  100               US            L
# 447                  100               US            L
# 524                  100               US            L
# 550                    0               US            L
# 551                    0               US            L

# %%
L_company_df.describe()
# Out:
#          work_year        salary    salary_in_usd   remote_ratio
# count    51.000000      51.000000        51.000000     51.000000
# mean   2021.156863  138729.411765    138729.411765     70.588235
# std       0.703493   59568.663890     59568.663890     42.633872
# min    2020.000000   58000.000000     58000.000000      0.000000
# 25%    2021.000000  100400.000000    100400.000000     50.000000
# 50%    2021.000000  135000.000000    135000.000000    100.000000
# 75%    2022.000000  162500.000000    162500.000000    100.000000
# max    2022.000000  412000.000000    412000.000000    100.000000

# %%
M_company_df = top_3_df[top_3_df['company_size'] == "M"]
M_company_df
# Out:
#             work_year experience_level employment_type       job_title  \
# Uni_number
# 57               2020               MI              FT  Data Scientist
# 59               2020               MI              FT  Data Scientist
# 79               2021               EN              FT    Data Analyst
# 108              2021               SE              FT   Data Engineer
# 122              2021               EN              FT    Data Analyst
# ...               ...              ...             ...             ...
# 599              2022               MI              FT  Data Scientist
# 602              2022               SE              FT   Data Engineer
# 603              2022               SE              FT   Data Engineer
# 604              2022               SE              FT    Data Analyst
# 605              2022               SE              FT    Data Analyst
#
#              salary  salary_currency   salary_in_usd  employee_residence  \
# Uni_number
# 57            118000             USD           118000                 US
# 59            138350             USD           138350                 US
# 79             80000             USD            80000                 US
# 108           150000             USD           150000                 US
# 122            50000             USD            50000                 US
# ...              ...             ...              ...                ...
# 599           130000             USD           130000                 US
# 602           154000             USD           154000                 US
# 603           126000             USD           126000                 US
# 604           129000             USD           129000                 US
# 605           150000             USD           150000                 US
#
#             remote_ratio company_location company_size
# Uni_number
# 57                   100               US            M
# 59                   100               US            M
# 79                   100               US            M
# 108                  100               US            M
# 122                  100               US            M
# ...                  ...              ...          ...
# 599                  100               US            M
# 602                  100               US            M
# 603                  100               US            M
# 604                    0               US            M
# 605                  100               US            M
#
# [169 rows x 11 columns]

# %%
M_company_df.describe()
# Out:
#          work_year        salary    salary_in_usd   remote_ratio
# count   169.000000     169.000000       169.000000    169.000000
# mean   2021.917160  136211.881657    136211.881657     79.289941
# std       0.316606   45452.942570     45452.942570     40.643250
# min    2020.000000   25000.000000     25000.000000      0.000000
# 25%    2022.000000  104890.000000    104890.000000    100.000000
# 50%    2022.000000  132000.000000    132000.000000    100.000000
# 75%    2022.000000  160080.000000    160080.000000    100.000000
# max    2022.000000  324000.000000    324000.000000    100.000000

# %%
S_company_df = top_3_df[top_3_df['company_size'] == "S"]
S_company_df
# Out:
#             work_year experience_level employment_type       job_title  \
# Uni_number
# 68               2020               EN              FT  Data Scientist
# 107              2021               SE              FT   Data Engineer
# 118              2021               EN              FT    Data Analyst
# 134              2021               EN              FT  Data Scientist
# 143              2021               MI              FT  Data Scientist
# 172              2021               EN              FT    Data Analyst
# 251              2021               EN              FT  Data Scientist
# 367              2022               MI              FT    Data Analyst
# 406              2022               MI              FT    Data Analyst
# 512              2022               EN              FT   Data Engineer
#
#              salary  salary_currency   salary_in_usd  employee_residence  \
# Uni_number
# 68            105000             USD           105000                 US
# 107           115000             USD           115000                 US
# 118            90000             USD            90000                 US
# 134           100000             USD           100000                 US
# 143            82500             USD            82500                 US
# 172            60000             USD            60000                 US
# 251            90000             USD            90000                 US
# 367            58000             USD            58000                 US
# 406            58000             USD            58000                 US
# 512            65000             USD            65000                 US
#
#             remote_ratio company_location company_size
# Uni_number
# 68                   100               US            S
# 107                  100               US            S
# 118                  100               US            S
# 134                    0               US            S
# 143                  100               US            S
# 172                  100               US            S
# 251                  100               US            S
# 367                    0               US            S
# 406                    0               US            S
# 512                  100               US            S

# %%
S_company_df.describe()
# Out:
#          work_year        salary    salary_in_usd   remote_ratio
# count    10.000000      10.000000        10.000000     10.000000
# mean   2021.200000   82350.000000     82350.000000     70.000000
# std       0.632456   21066.099676     21066.099676     48.304589
# min    2020.000000   58000.000000     58000.000000      0.000000
# 25%    2021.000000   61250.000000     61250.000000     25.000000
# 50%    2021.000000   86250.000000     86250.000000    100.000000
# 75%    2021.750000   97500.000000     97500.000000    100.000000
# max    2022.000000  115000.000000    115000.000000    100.000000

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Final_Project"
engine = create_engine(db_string)

# %%
us_df.to_sql(name='us_sql', if_exists='replace', con=engine)
rows_imported = 0
